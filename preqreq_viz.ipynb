# %%
import pickle
import pandas as pd
from pyvis.network import Network
import networkx as nx

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

with open('./CS_Courses.pkl', 'rb') as df_file:
    df = pickle.load(df_file)

null_value = df.loc[1]['prerequisites']

no_prereq = [0, 2, 3, 6]

for i in range(len(df.index)):
    if df.loc[i]['prerequisites'] == null_value:
        no_prereq.append(i)

df2 = df.drop(index=no_prereq)
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#                                           description                                        course code credits                                      terms offered                                        instructors                                      prerequisites
# 0   Comprehensive overview of programming in C, us...         COMP 206 Introduction to Software Systems        3                          Fall 2022, Winter 2023 \n                           D&#x27;Silva, Joseph  \n                            COMP 202 or COMP 250 \n
# 1   Mathematical tools (binary numbers, induction,...        COMP 250 Introduction to Computer Science         3                      Fall 2022, Winter 2023     \n         Alberini, Giulia  Alberini, Giulia      \n  Familiarity with a high level programming lang...
# ...

# %%
net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", directed=True, select_menu=True)

for i in range(len(df2)):
    net.add_node(i, label=df2.loc[i]['course code'][:8])

net.add_node(82, "COMP 202")
net.add_node(83, "MATH 235", color='red')
net.add_node(84, "MATH 240", color='red')
net.add_node(85, "MATH 318", color='red')
net.add_node(86, "COMP 230")
net.add_node(87, "PHIL 210", color='yellow')
net.add_node(88, "COMP 273")
net.add_node(89, "COMP 208")
net.add_node(90, "MATH 222", color='red')
net.add_node(91, "MATH 223", color='red')
net.add_node(92, "MATH 362", color='red')
net.add_node(93, "COMP 361D1")
net.add_node(94, "BIOL 200", color='blue')
net.add_node(95, "15 Computer Science credits.", color='black')
net.add_node(96, "9 credits of COMP courses and 9 credits of BIOL courses.", color='black')
net.add_node(97, "ECSE 427", color='green')
net.add_node(98, "ECSE 321", color='green')
net.add_node(99, "MATH 323", color='red')
net.add_node(100, "MATH 203", color='red')
net.add_node(101, "BIOL 309", color='blue')
net.add_node(102, "ECSE 305", color='green')
net.add_node(103, "ECSE 205", color='green')
net.add_node(104, "MATH 350", color='red')
net.add_node(105, "MATH 454", color='red')
net.add_node(106, "MATH 487", color='red')
net.add_node(107, "MATH 462", color='red')
net.add_node(108, "MATH 324", color='red')
net.add_node(109, "ECSE 551", color='green')
net.add_node(110, "BIOL 202", color='blue')
net.add_node(111, "BIOL 302", color='blue')
net.add_node(112, "MATH 417", color='red')
net.add_node(113, "COMP 601D1")
net.add_node(114, "COMP 601N1")
net.add_node(115, "COMP 435")
net.add_node(116, "COMP 616D1")
net.add_node(117, "COMP 616N1")
net.add_node(119, "COMP 526")
net.add_node(120, "ECSE 526", color='green')
net.add_node(121, "COMP 700D1")

#White = requirement
#Same colour = OR
#Different colour = AND
#Colour order: Yellow, Blue, Green
#Red means OR + AND. (Used only for COMP 562: Theory of Machine Learning)
# 
# eg. COMP 250 is white, COMP 202 + 206 + 273 is red
# Prerequisites: COMP 250 OR (COMP 202, COMP 206, AND COMP 273). 
#
#eg. COMP 250 + COMP 206 is white, COMP 251 + COMP 252 are blue, COMP 360 and COMP 362 are yellow.
#Prerequisites: COMP 250, COMP 206, (COMP 251 OR COMP 252), AND (COMP 360 OR COMP 362)

net.add_edge(1, 0, color='yellow')
net.add_edge(82, 0, color='yellow')
net.add_edge(82, 1, color='white')
net.add_edge(1, 2, color='white')
net.add_edge(83, 2, color='yellow')
net.add_edge(84, 2, color='yellow')
net.add_edge(1, 3, color='white')
net.add_edge(83, 3, color='yellow')
net.add_edge(84, 3, color='yellow')
net.add_edge(1, 4, color='white')
net.add_edge(83, 4, color='yellow')
net.add_edge(84, 4, color='yellow')
net.add_edge(85, 4, color='yellow')
net.add_edge(86, 4, color='yellow')
net.add_edge(87, 4, color='yellow')
net.add_edge(0, 5, color='white')
net.add_edge(1, 5, color='white')
net.add_edge(0, 6, color='white')
net.add_edge(88, 7, color='white')
net.add_edge(88, 8, color='white')
net.add_edge(0, 9, color='white')
net.add_edge(1, 10, color='white')
net.add_edge(0, 10, color='yellow')
net.add_edge(89, 10, color='yellow')
net.add_edge(2, 11, color='white')
net.add_edge(1, 12, color='white')
net.add_edge(84, 12, color='white')
net.add_edge(90, 13, color='white')
net.add_edge(91, 13, color='white')
net.add_edge(82, 13, color='yellow')
net.add_edge(89, 13, color='yellow')
net.add_edge(1, 13, color='yellow')
net.add_edge(2, 14, color='yellow')
net.add_edge(3, 14, color='yellow')
net.add_edge(83, 14, color='blue')
net.add_edge(84, 14, color='blue')
net.add_edge(92, 14, color='blue')
net.add_edge(0, 15, color='white')
net.add_edge(1, 15, color='white')
net.add_edge(93, 16, color='white')
net.add_edge(3, 17, color='white')
net.add_edge(94, 18, color='white')
net.add_edge(0, 19, color='white')
net.add_edge(1, 19, color='white')
net.add_edge(95, 20, color='white')
net.add_edge(2, 21, color='white')
net.add_edge(96, 21, color='white')
net.add_edge(96, 22, color='white')
net.add_edge(96, 23, color='white')
net.add_edge(96, 24, color='white')
net.add_edge(96, 23, color='white')
net.add_edge(2, 25, color='white')
net.add_edge(4, 25, color='white')
net.add_edge(8, 25, color='yellow')
net.add_edge(97, 25, color='yellow')
net.add_edge(2, 26, color='white')
net.add_edge(91, 26, color='white')
net.add_edge(98, 26, color='yellow')
net.add_edge(0, 26, color='yellow')
net.add_edge(0, 27, color='white')
net.add_edge(2, 27, color='white')
net.add_edge(4, 27, color='white')
net.add_edge(0, 28, color='yellow')
net.add_edge(98, 28, color='yellow')
net.add_edge(99, 28, color='white')
net.add_edge(2, 28, color='white')
net.add_edge(1, 29, color='white')
net.add_edge(84, 29, color='white')
net.add_edge(2, 30, color='white')
net.add_edge(90, 30, color='white')
net.add_edge(91, 30, color='white')
net.add_edge(99, 30, color='white')
net.add_edge(2, 31, color='white')
net.add_edge(99, 31, color='white')
net.add_edge(100, 31, color='yellow')
net.add_edge(101, 31, color='yellow')
net.add_edge(8, 32, color='white')
net.add_edge(2, 32, color='white')
net.add_edge(91, 33, color='white')
net.add_edge(99, 33, color='white')
net.add_edge(0, 33, color='white')
net.add_edge(1, 33, color='white')
net.add_edge(88, 34, color='white')
net.add_edge(4, 34, color='white')
net.add_edge(2, 35, color='white')
net.add_edge(91, 35, color='white')
net.add_edge(5, 35, color='yellow')
net.add_edge(16, 35, color='yellow')
net.add_edge(4, 36, color='white')
net.add_edge(11, 36, color='white')
net.add_edge(2, 37, color='white')
net.add_edge(11, 37, color='white')
net.add_edge(4, 38, color='white')
net.add_edge(5, 39, color='white')
net.add_edge(11, 40, color='white')
net.add_edge(98, 41, color='yellow')
net.add_edge(5, 41, color='yellow')
net.add_edge(16, 41, color='yellow')
net.add_edge(8, 42, color='yellow')
net.add_edge(97, 42, color='yellow')
net.add_edge(14, 43, color='yellow')
net.add_edge(13, 43, color='yellow')
net.add_edge(14, 44, color='yellow')
net.add_edge(17, 44, color='yellow')
net.add_edge(99, 44, color='white')
net.add_edge(90, 45, color='white')
net.add_edge(91, 45, color='white')
net.add_edge(99, 45, color='white')
net.add_edge(99, 46, color='yellow')
net.add_edge(102, 46, color='yellow')
net.add_edge(2, 46, color='blue')
net.add_edge(3, 46, color='blue')
net.add_edge(99, 47, color='yellow')
net.add_edge(103, 47, color='yellow')
net.add_edge(102, 47, color='yellow')
net.add_edge(104, 48, color='yellow')
net.add_edge(17, 48, color='yellow')
net.add_edge(17, 49, color='yellow')
net.add_edge(104, 49, color='yellow')
net.add_edge(105, 49, color='yellow')
net.add_edge(106, 49, color='yellow')
net.add_edge(17, 50, color='yellow')
net.add_edge(104, 50, color='yellow')
net.add_edge(5, 51, color='white')
net.add_edge(90, 52, color='white')
net.add_edge(91, 52, color='white')
net.add_edge(0, 52, color='white')
net.add_edge(1, 52, color='white')
net.add_edge(2, 53, color='white')
net.add_edge(90, 53, color='white')
net.add_edge(91, 53, color='white')
net.add_edge(90, 54, color='white')
net.add_edge(91, 54, color='white')
net.add_edge(0, 54, color='white')
net.add_edge(1, 54, color='white')
net.add_edge(2, 55, color='white')
net.add_edge(99, 55, color='yellow')
net.add_edge(100, 55, color='yellow')
net.add_edge(101, 55, color='yellow')
net.add_edge(107, 56, color='yellow')
net.add_edge(30, 56, color='yellow')
net.add_edge(47, 56, color='red')
net.add_edge(90, 56, color='red')
net.add_edge(91, 56, color='red')
net.add_edge(108, 56, color='red')
net.add_edge(109, 56, color='yellow')
net.add_edge(31, 57, color='white')
net.add_edge(110, 58, color='yellow')
net.add_edge(111, 58, color='yellow')
net.add_edge(108, 58, color='white')
net.add_edge(30, 58, color='blue')
net.add_edge(47, 58, color='blue')
net.add_edge(14, 59, color='white')
net.add_edge(91, 59, color='white')
net.add_edge(59, 60, color='yellow')
net.add_edge(112, 60, color='yellow')
net.add_edge(5, 62, color='white')
net.add_edge(28, 62, color='yellow')
net.add_edge(47, 62, color='yellow')
net.add_edge(2, 63, color='white')
net.add_edge(99, 63, color='white')
net.add_edge(108, 63, color='white')
net.add_edge(113, 66, color='white')
net.add_edge(114, 67, color='white')
net.add_edge(27, 68, color='white')
net.add_edge(115, 68, color='yellow')
net.add_edge(42, 68, color='yellow')
net.add_edge(32, 68, color='yellow')
net.add_edge(116, 69, color='white')
net.add_edge(117, 70, color='white')
net.add_edge(2, 72, color='white')
net.add_edge(4, 72, color='white')
net.add_edge(99, 73, color='white')
net.add_edge(108, 73, color='white')
net.add_edge(13, 73, color='white')
net.add_edge(44, 74, color='white')
net.add_edge(44, 75, color='white')
net.add_edge(28, 76, color='yellow')
net.add_edge(119, 76, color='yellow')
net.add_edge(120, 76, color='yellow')
net.add_edge(14, 76, color='blue')
net.add_edge(99, 76, color='blue')
net.add_edge(102, 76, color='blue')
net.add_edge(90, 77, color='white')
net.add_edge(91, 77, color='white')
net.add_edge(14, 77, color='white')
net.add_edge(30, 77, color='yellow')
net.add_edge(47, 77, color='yellow')
net.add_edge(8, 78, color='white')
net.add_edge(25, 79, color='white')
net.add_edge(31, 80, color='white')
net.add_edge(121, 81, color='white')

net.show('prerequisites.html')
